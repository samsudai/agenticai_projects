# %% [markdown]
# # 📡 TelecomAI — Multi-Agent Customer Service System
#
# > **Built with:** LangGraph · GPT-4o-mini · text-embedding-3-small · FAISS Memory
#
# ---
#
# ### 🤖 Meet the Agents
#
# | Agent | Name | Role |
# |-------|------|------|
# | 🟢 | **Nova** | Front-Desk Supervisor — Greets, verifies & routes |
# | 🔵 | **Rajan** | Billing Specialist — Invoices, payments, plans |
# | 🟡 | **Priya** | Technical Support — Network, SIM, connectivity |
# | 🟣 | **Arjun** | Retention Specialist — Deals, discounts, cancellations |
#
# ### 🧠 Memory
# - **Short-term:** Full conversation history per session
# - **Long-term:** Ticket IDs, events & summaries in FAISS (text-embedding-3-small) — retrieved semantically each turn

# %% [markdown]
# ## 🔧 Step 1 — Install Dependencies

# %%
# !pip install -q langgraph langchain langchain-openai langchain-community openai faiss-cpu tiktoken
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 75.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 81.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.3/558.3 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %% [markdown]
# ## 🔑 Step 2 — Set Your OpenAI API Key

# %%
import os
import getpass
from google.colab import userdata

#if "OPENAI_API_KEY" not in os.environ:
#    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key: ")
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

print("API Key set!")
# Out:
# API Key set!

# %% [markdown]
# ## 📦 Step 3 — Imports

# %%
import json
import random
from datetime import datetime
from typing import Annotated, Any, Dict, List, TypedDict

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage, ToolMessage
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document

from langgraph.graph import END, START, StateGraph
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode

print("All imports OK!")
print(f"Session: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# /tmp/ipykernel_1167/3967317732.py:9: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# All imports OK!
# Session: 2026-07-10 17:55:18

# %% [markdown]
# ## 🤖 Step 4 — Models & Memory Store

# %%
# LLM
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

# Embeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# FAISS Vector Store (bootstrapped with one doc)
memory_store = FAISS.from_documents(
    [Document(page_content="TelecomAI memory initialized.", metadata={"type": "init"})],
    embeddings
)

# Shared session state
session_state: Dict[str, Any] = {
    "customer_id": None,
    "account_name": None,
    "open_tickets": [],
    "plan": None,
    "verified": False,
}

print("GPT-4o-mini ready!")
print("text-embedding-3-small ready!")
print("FAISS memory store ready!")
# Out:
# GPT-4o-mini ready!
# text-embedding-3-small ready!
# FAISS memory store ready!

# %% [markdown]
# ## 🧠 Step 5 — Memory Helpers

# %%
def save_to_memory(content: str, metadata: dict):
    doc = Document(page_content=content, metadata=metadata)
    memory_store.add_documents([doc])

def recall_from_memory(query: str, k: int = 4) -> str:
    results = memory_store.similarity_search(query, k=k)
    relevant = [r for r in results if r.metadata.get("type") != "init"]
    if not relevant:
        return "No prior memory found."
    lines = []
    for r in relevant:
        meta_str = ", ".join(f"{mk}: {mv}" for mk, mv in r.metadata.items())
        lines.append(f"[{meta_str}] {r.page_content}")
    return "\n".join(lines)

def create_ticket(issue_type: str, description: str, agent: str) -> dict:
    ticket = {
        "ticket_id": f"TKT-{random.randint(10000, 99999)}",
        "issue_type": issue_type,
        "description": description,
        "status": "Open",
        "assigned_to": agent,
        "created_at": datetime.now().strftime("%Y-%m-%d %H:%M"),
        "customer_id": session_state.get("customer_id", "Unknown"),
    }
    session_state["open_tickets"].append(ticket)
    save_to_memory(
        f"Ticket {ticket['ticket_id']}: {issue_type} - {description}. Status: Open. Agent: {agent}.",
        {"type": "ticket", "ticket_id": ticket["ticket_id"], "status": "Open", "agent": agent}
    )
    return ticket

print("Memory helpers ready!")
# Out:
# Memory helpers ready!

# %% [markdown]
# ## 🛠️ Step 6 — Dummy Telecom Tools

# %%
# ── RAJAN: BILLING TOOLS ──────────────────────────────────────────────────────

@tool
def lookup_invoice(customer_id: str) -> str:
    """Look up the latest invoice for a customer."""
    dummy = {
        "C001": {"id": "INV-8821", "amount": "999 INR", "due": "2025-06-01", "status": "Unpaid"},
        "C002": {"id": "INV-9934", "amount": "1499 INR", "due": "2025-05-20", "status": "Paid"},
    }
    inv = dummy.get(customer_id, {"id": "INV-0000", "amount": "599 INR", "due": "2025-06-10", "status": "Unpaid"})
    result = f"Invoice {inv['id']} | Amount: {inv['amount']} | Due: {inv['due']} | Status: {inv['status']}"
    save_to_memory(f"Customer {customer_id} invoice: {result}", {"type": "billing", "customer_id": customer_id})
    return result

@tool
def process_payment(customer_id: str, amount: str) -> str:
    """Process a payment for the customer."""
    txn_id = f"TXN-{random.randint(100000, 999999)}"
    result = f"Payment of {amount} processed! Transaction ID: {txn_id}"
    save_to_memory(f"Customer {customer_id} paid {amount}. TXN: {txn_id}", {"type": "payment", "txn_id": txn_id, "customer_id": customer_id})
    return result

@tool
def upgrade_plan(customer_id: str, new_plan: str) -> str:
    """Upgrade or change the customer's telecom plan."""
    plans = {
        "basic": "399 INR/mo - 2GB/day",
        "standard": "699 INR/mo - 3GB/day",
        "premium": "999 INR/mo - Unlimited",
        "ultra": "1499 INR/mo - Unlimited + OTT"
    }
    details = plans.get(new_plan.lower(), f"{new_plan} - custom pricing")
    session_state["plan"] = new_plan.lower()
    result = f"Plan upgraded to {new_plan.upper()} ({details}) for customer {customer_id}."
    save_to_memory(result, {"type": "plan_change", "customer_id": customer_id, "plan": new_plan})
    return result

# ── PRIYA: TECH SUPPORT TOOLS ─────────────────────────────────────────────────

@tool
def run_network_diagnostic(customer_id: str, issue_type: str) -> str:
    """Run a network diagnostic for a customer's connection issue."""
    findings = [
        "Signal strength 72% - slight interference detected.",
        "Network congestion in your zone during peak hours (7PM-10PM).",
        "SIM card may need re-seating. Try removing and reinserting.",
        "Tower maintenance scheduled nearby. ETA: 2 hours.",
    ]
    finding = random.choice(findings)
    ticket = create_ticket("Network Issue", f"{issue_type} - Diagnostic: {finding}", "Priya")
    return f"Diagnostic complete. Finding: {finding}\nTicket raised: {ticket['ticket_id']}"

@tool
def reset_network_settings(customer_id: str) -> str:
    """Reset the customer's network settings remotely."""
    result = f"Network settings reset for customer {customer_id}. Please restart your device. Takes ~2 minutes."
    save_to_memory(result, {"type": "tech_action", "customer_id": customer_id, "action": "network_reset"})
    return result

@tool
def check_tower_status(area_code: str) -> str:
    """Check telecom tower status for a given area."""
    statuses = [
        "All towers operational.",
        "Partial outage - 1 tower under maintenance.",
        "Major outage - engineers dispatched."
    ]
    return f"Tower status for area {area_code}: {random.choice(statuses)}"

# ── ARJUN: RETENTION TOOLS ────────────────────────────────────────────────────

@tool
def get_available_offers(customer_id: str) -> str:
    """Fetch personalized retention offers for the customer."""
    offers = [
        "30% off next 3 months if you stay on Premium.",
        "Free 6-month OTT bundle (Netflix + Hotstar) with upgrade.",
        "Double data for 60 days at no extra charge.",
        "Cashback of 500 INR on next recharge.",
    ]
    selected = random.sample(offers, k=2)
    result = "\n".join(f"- {o}" for o in selected)
    save_to_memory(f"Offers shown to {customer_id}: {result}", {"type": "offer", "customer_id": customer_id})
    return result

@tool
def process_cancellation_request(customer_id: str, reason: str) -> str:
    """Log a cancellation or port-out request."""
    ticket = create_ticket("Cancellation Request", reason, "Arjun")
    return (
        f"Cancellation request logged. Ticket: {ticket['ticket_id']}\n"
        f"A retention specialist will call you within 24 hours."
    )

# ── NOVA: GENERAL TOOLS ───────────────────────────────────────────────────────

@tool
def verify_customer(customer_id: str, phone_last4: str) -> str:
    """Verify a customer's identity using their ID and last 4 digits of phone."""
    if len(phone_last4) == 4 and phone_last4.isdigit():
        session_state["customer_id"] = customer_id
        session_state["verified"] = True
        session_state["account_name"] = f"Customer-{customer_id}"
        save_to_memory(
            f"Customer {customer_id} verified at {datetime.now().strftime('%H:%M')}.",
            {"type": "verification", "customer_id": customer_id}
        )
        return f"Identity verified! Welcome, Customer {customer_id}."
    return "Verification failed. Please check your Customer ID and phone number."

@tool
def check_ticket_status(ticket_id: str) -> str:
    """Check the status of a support ticket."""
    for t in session_state["open_tickets"]:
        if t["ticket_id"] == ticket_id:
            return (
                f"Ticket {ticket_id}\n"
                f"  Issue: {t['issue_type']}\n"
                f"  Status: {t['status']}\n"
                f"  Agent: {t['assigned_to']}\n"
                f"  Created: {t['created_at']}"
            )
    mem = recall_from_memory(f"ticket {ticket_id}")
    if "No prior memory" not in mem:
        return f"From memory:\n{mem}"
    return f"Ticket {ticket_id} not found. Please check the ID."

print("All 9 tools ready!")
print("  Billing : lookup_invoice, process_payment, upgrade_plan")
print("  Tech    : run_network_diagnostic, reset_network_settings, check_tower_status")
print("  Retain  : get_available_offers, process_cancellation_request")
print("  General : verify_customer, check_ticket_status")
# Out:
# All 9 tools ready!
#   Billing : lookup_invoice, process_payment, upgrade_plan
#   Tech    : run_network_diagnostic, reset_network_settings, check_tower_status
#   Retain  : get_available_offers, process_cancellation_request
#   General : verify_customer, check_ticket_status

# %% [markdown]
# ## 🕸️ Step 7 — Build the LangGraph

# %%
BILLING_TOOLS = [lookup_invoice, process_payment, upgrade_plan]
TECH_TOOLS    = [run_network_diagnostic, reset_network_settings, check_tower_status]
RETAIN_TOOLS  = [get_available_offers, process_cancellation_request]
NOVA_TOOLS    = [verify_customer, check_ticket_status]
ALL_TOOLS     = NOVA_TOOLS + BILLING_TOOLS + TECH_TOOLS + RETAIN_TOOLS

nova_llm  = llm.bind_tools(ALL_TOOLS)
rajan_llm = llm.bind_tools(BILLING_TOOLS)
priya_llm = llm.bind_tools(TECH_TOOLS)
arjun_llm = llm.bind_tools(RETAIN_TOOLS)

# ── State ─────────────────────────────────────────────────────────────────────
class TelecomState(TypedDict):
    messages: Annotated[list, add_messages]
    current_agent: str
    memory_context: str

# ── System Prompts ────────────────────────────────────────────────────────────
def nova_system(ctx):
    return (
        "You are Nova, the friendly Front-Desk Supervisor at TelecomAI.\n"
        "Greet customers warmly, verify identity when needed, and route them to the right specialist.\n"
        "- Billing/payment/invoice/plan -> say: Connecting you to Rajan (Billing)\n"
        "- Network/connectivity/signal/tower -> say: Connecting you to Priya (Tech Support)\n"
        "- Cancel/port/offers/discount -> say: Connecting you to Arjun (Retention)\n"
        "- For sensitive requests, ask them to verify first using verify_customer.\n"
        "- Use check_ticket_status for any ticket IDs mentioned.\n"
        f"\nMEMORY:\n{ctx}\n\nSESSION: {json.dumps(session_state)}"
    )

def rajan_system(ctx):
    return (
        "You are Rajan, TelecomAI's Billing Specialist.\n"
        "Handle: invoices, payments, plan upgrades, billing disputes.\n"
        "Always run lookup_invoice before processing payments. Confirm amounts first.\n"
        f"\nMEMORY:\n{ctx}\n\nSESSION: {json.dumps(session_state)}"
    )

def priya_system(ctx):
    return (
        "You are Priya, TelecomAI's Technical Support Engineer.\n"
        "Handle: network issues, slow internet, dropped calls, SIM problems, tower outages.\n"
        "Always run a diagnostic first. Raise a ticket if unresolved and share the ticket ID.\n"
        f"\nMEMORY:\n{ctx}\n\nSESSION: {json.dumps(session_state)}"
    )

def arjun_system(ctx):
    return (
        "You are Arjun, TelecomAI's Retention Specialist.\n"
        "Handle: cancellations, port-out, exclusive deals, loyalty discounts.\n"
        "Always fetch personalized offers before discussing cancellation. Be empathetic.\n"
        f"\nMEMORY:\n{ctx}\n\nSESSION: {json.dumps(session_state)}"
    )

# ── Agent Nodes ───────────────────────────────────────────────────────────────
def nova_node(state):
    ctx = recall_from_memory(state["messages"][-1].content)
    resp = nova_llm.invoke([SystemMessage(content=nova_system(ctx))] + state["messages"])
    return {"messages": [resp], "current_agent": "nova", "memory_context": ctx}

def rajan_node(state):
    ctx = recall_from_memory(state["messages"][-1].content)
    resp = rajan_llm.invoke([SystemMessage(content=rajan_system(ctx))] + state["messages"])
    return {"messages": [resp], "current_agent": "rajan", "memory_context": ctx}

def priya_node(state):
    ctx = recall_from_memory(state["messages"][-1].content)
    resp = priya_llm.invoke([SystemMessage(content=priya_system(ctx))] + state["messages"])
    return {"messages": [resp], "current_agent": "priya", "memory_context": ctx}

def arjun_node(state):
    ctx = recall_from_memory(state["messages"][-1].content)
    resp = arjun_llm.invoke([SystemMessage(content=arjun_system(ctx))] + state["messages"])
    return {"messages": [resp], "current_agent": "arjun", "memory_context": ctx}

# ── Routing ───────────────────────────────────────────────────────────────────
def route_nova(state):
    last = state["messages"][-1]
    if hasattr(last, "tool_calls") and last.tool_calls:
        return "tools"
    content = last.content.lower() if hasattr(last, "content") else ""
    if "rajan" in content or "billing" in content:
        return "rajan"
    if "priya" in content or "tech" in content:
        return "priya"
    if "arjun" in content or "retention" in content:
        return "arjun"
    return END

def specialist_route(state):
    last = state["messages"][-1]
    if hasattr(last, "tool_calls") and last.tool_calls:
        return "tools"
    return END

def after_tools(state):
    return state.get("current_agent", "nova")

# ── Compile ───────────────────────────────────────────────────────────────────
tool_node = ToolNode(tools=ALL_TOOLS)
builder = StateGraph(TelecomState)

builder.add_node("nova",  nova_node)
builder.add_node("rajan", rajan_node)
builder.add_node("priya", priya_node)
builder.add_node("arjun", arjun_node)
builder.add_node("tools", tool_node)

builder.add_edge(START, "nova")

builder.add_conditional_edges("nova", route_nova, {
    "tools": "tools", "rajan": "rajan",
    "priya": "priya", "arjun": "arjun", END: END
})
builder.add_conditional_edges("rajan", specialist_route, {"tools": "tools", END: END})
builder.add_conditional_edges("priya", specialist_route, {"tools": "tools", END: END})
builder.add_conditional_edges("arjun", specialist_route, {"tools": "tools", END: END})
builder.add_conditional_edges("tools", after_tools, {
    "nova": "nova", "rajan": "rajan", "priya": "priya", "arjun": "arjun"
})

graph = builder.compile()
print("LangGraph compiled!")
# Out:
# LangGraph compiled!

# %% [markdown]
# ## 📊 Step 8 — Visualize the Graph

# %%
try:
    from IPython.display import Image, display
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    print(graph.get_graph().draw_mermaid())

# %% [markdown]
# ## 💬 Step 9 — Chat Interface

# %%
AGENT_DISPLAY = {
    "nova":  "Nova  (Supervisor)",
    "rajan": "Rajan (Billing)",
    "priya": "Priya (Tech Support)",
    "arjun": "Arjun (Retention)",
}

conversation_history: List = []

def chat(user_input: str) -> str:
    global conversation_history

    if session_state.get("customer_id"):
        save_to_memory(
            f"User said: {user_input}",
            {"type": "conversation", "customer_id": session_state["customer_id"]}
        )
    conversation_history.append(HumanMessage(content=user_input))
    result = graph.invoke(
        {"messages": conversation_history, "current_agent": "nova", "memory_context": ""},
        config={"recursion_limit": 20}
    )
    final_msg = None
    for msg in reversed(result["messages"]):
        if isinstance(msg, AIMessage) and msg.content:
            final_msg = msg
            break
    conversation_history = result["messages"]
    agent = result.get("current_agent", "nova")
    label = AGENT_DISPLAY.get(agent, "Agent")
    text = final_msg.content if final_msg else "(no response)"
    print(f"\n{'='*60}")
    print(f"You   : {user_input}")
    print(f"{'-'*60}")
    print(f"{label}:")
    print(text)
    print(f"{'='*60}")
    return text

def reset_session():
    global conversation_history, session_state
    conversation_history = []
    session_state.update({"customer_id": None, "account_name": None,
                          "open_tickets": [], "plan": None, "verified": False})
    print("Session reset! (Vector memory preserved)")

def show_memory(query="customer ticket billing"):
    print("\nMemory recall:")
    print(recall_from_memory(query, k=5))

def show_state():
    print("\nSession State:")
    for k, v in session_state.items():
        if k != "open_tickets":
            print(f"  {k}: {v}")
    print(f"\nOpen Tickets ({len(session_state['open_tickets'])}):")
    for t in session_state["open_tickets"]:
        print(f"  [{t['ticket_id']}] {t['issue_type']} | {t['status']} | {t['assigned_to']}")

print("Chat ready!")
print("Commands: chat('msg') | reset_session() | show_memory() | show_state()")
# Out:
# Chat ready!
# Commands: chat('msg') | reset_session() | show_memory() | show_state()

# %% [markdown]
# ## 🎬 Step 10 — Demo Conversation

# %%
chat("Hi, I need help with my account")
# Out:
# ============================================================
# You   : Hi, I need help with my account
# ------------------------------------------------------------
# Rajan (Billing):
# To assist you better, could you please provide your customer ID or account name? This will help me look up your account details.
# ============================================================
# 'To assist you better, could you please provide your customer ID or account name? This will help me look up your account details.'

# %%
chat("My customer ID is C001 and my phone ends in 7890")
# Out:
# ============================================================
# You   : My customer ID is C001 and my phone ends in 7890
# ------------------------------------------------------------
# Nova  (Supervisor):
# You're all set, Customer C001! How can I assist you with your account today?
# ============================================================
# "You're all set, Customer C001! How can I assist you with your account today?"

# %%
chat("I want to check my latest invoice and pay it")
# Out:
# ============================================================
# You   : I want to check my latest invoice and pay it
# ------------------------------------------------------------
# Rajan (Billing):
# Your latest invoice details are as follows:
#
# - **Invoice Number:** INV-8821
# - **Amount:** 999 INR
# - **Due Date:** 2025-06-01
# - **Status:** Unpaid
#
# Would you like to proceed with the payment of 999 INR?
# ============================================================
# 'Your latest invoice details are as follows:\n\n- **Invoice Number:** INV-8821\n- **Amount:** 999 INR\n- **Due Date:** 2025-06-01\n- **Status:** Unpaid\n\nWould you like to proceed with the payment of 999 INR?'

# %%
chat("Also my internet has been very slow for 2 days")
# Out:
# ============================================================
# You   : Also my internet has been very slow for 2 days
# ------------------------------------------------------------
# Priya (Tech Support):
# I've completed the diagnostic for your slow internet issue, and it appears that there is network congestion in your area during peak hours (7 PM - 10 PM).
#
# Additionally, I have reset your network settings. Please restart your device; it should take about 2 minutes.
#
# I've also raised a ticket for the slow internet issue. Here are the details:
#
# - **Ticket ID:** TKT-66007
# - **Status:** Open
#
# If the issue persists after restarting your device, please let me know!
# ============================================================
# "I've completed the diagnostic for your slow internet issue, and it appears that there is network congestion in your area during peak hours (7 PM - 10 PM). \n\nAdditionally, I have reset your network settings. Please restart your device; it should take about 2 minutes.\n\nI've also raised a ticket for the slow internet issue. Here are the details:\n\n- **Ticket ID:** TKT-66007\n- **Status:** Open\n\nIf the issue persists after restarting your device, please let me know!"

# %%
chat("What is the status of my latest ticket?")
# Out:
# ============================================================
# You   : What is the status of my latest ticket?
# ------------------------------------------------------------
# Nova  (Supervisor):
# Your latest ticket (TKT-66007) is currently **Open**. It was raised for a network issue related to slow internet due to congestion in your area during peak hours.
#
# If you have any further questions or need additional assistance, feel free to ask!
# ============================================================
# 'Your latest ticket (TKT-66007) is currently **Open**. It was raised for a network issue related to slow internet due to congestion in your area during peak hours.\n\nIf you have any further questions or need additional assistance, feel free to ask!'

# %%
chat("I am thinking of cancelling my plan, the service is bad")
# Out:
# ============================================================
# You   : I am thinking of cancelling my plan, the service is bad
# ------------------------------------------------------------
# Arjun (Retention):
# I understand that you're considering canceling your plan due to the service issues. Before we proceed, I’d like to offer you some exclusive deals that might enhance your experience:
#
# 1. **Free 6-month OTT bundle** (Netflix + Hotstar) with an upgrade.
# 2. **Cashback of 500 INR** on your next recharge.
#
# Would any of these offers interest you? I want to ensure you have the best experience possible before making a final decision.
# ============================================================
# "I understand that you're considering canceling your plan due to the service issues. Before we proceed, I’d like to offer you some exclusive deals that might enhance your experience:\n\n1. **Free 6-month OTT bundle** (Netflix + Hotstar) with an upgrade.\n2. **Cashback of 500 INR** on your next recharge.\n\nWould any of these offers interest you? I want to ensure you have the best experience possible before making a final decision."

# %%
chat("OK I will stay. Can you upgrade me to the Premium plan?")
# Out:
# ============================================================
# You   : OK I will stay. Can you upgrade me to the Premium plan?
# ------------------------------------------------------------
# Nova  (Supervisor):
# Your plan has been successfully upgraded to the **Premium plan** (999 INR/month - Unlimited).
#
# If you have any other questions or need further assistance, feel free to ask! Enjoy your upgraded plan!
# ============================================================
# 'Your plan has been successfully upgraded to the **Premium plan** (999 INR/month - Unlimited). \n\nIf you have any other questions or need further assistance, feel free to ask! Enjoy your upgraded plan!'

# %% [markdown]
# ## 🧠 Step 11 — Test Cross-Session Memory

# %%
reset_session()
# Out:
# Session reset! (Vector memory preserved)

# %%
chat("Hi, I am customer C001. I called earlier about a network problem. Any updates?")
# Out:
# ============================================================
# You   : Hi, I am customer C001. I called earlier about a network problem. Any updates?
# ------------------------------------------------------------
# Nova  (Supervisor):
# Hello! Let me check the status of your ticket regarding the network issue. One moment, please.
#
# Checking the status of ticket TKT-66007...
# ============================================================
# 'Hello! Let me check the status of your ticket regarding the network issue. One moment, please. \n\nChecking the status of ticket TKT-66007...'

# %%
show_memory("C001 network ticket billing")
# Out:
# Memory recall:
# [type: billing, customer_id: C001] Customer C001 invoice: Invoice INV-8821 | Amount: 999 INR | Due: 2025-06-01 | Status: Unpaid
# [type: ticket, ticket_id: TKT-66007, status: Open, agent: Priya] Ticket TKT-66007: Network Issue - slow internet - Diagnostic: Network congestion in your zone during peak hours (7PM-10PM).. Status: Open. Agent: Priya.
# [type: plan_change, customer_id: C001, plan: Premium] Plan upgraded to PREMIUM (999 INR/mo - Unlimited) for customer C001.
# [type: tech_action, customer_id: C001, action: network_reset] Network settings reset for customer C001. Please restart your device. Takes ~2 minutes.
# [type: verification, customer_id: C001] Customer C001 verified at 17:55.

# %% [markdown]
# ## 📊 Step 12 — Inspect State & Tickets

# %%
show_state()
# Out:
# Session State:
#   customer_id: None
#   account_name: None
#   plan: None
#   verified: False
#
# Open Tickets (0):

# %% [markdown]
# ## 🆓 Step 13 — Free Play / Interactive Loop

# %%
print("Interactive mode  |  type 'exit' to stop, 'reset', 'memory', 'state' for commands")
print("=" * 60)
while True:
    try:
        user_input = input("\nYou: ").strip()
    except (EOFError, KeyboardInterrupt):
        print("\nGoodbye!")
        break
    if not user_input:
        continue
    if user_input.lower() == "exit":
        print("Thanks for using TelecomAI!")
        break
    elif user_input.lower() == "reset":
        reset_session()
    elif user_input.lower() == "memory":
        show_memory()
    elif user_input.lower() == "state":
        show_state()
    else:
        chat(user_input)
# Out:
# Interactive mode  |  type 'exit' to stop, 'reset', 'memory', 'state' for commands
# ============================================================
#
# You: exit
# Thanks for using TelecomAI!

# %%
# ============================================================
# BEAUTIFUL MULTI AGENT DEBUG SYSTEM
# COMPLETE OBSERVABILITY VERSION
# ============================================================

# ============================================================
# INSTALL
# ============================================================

# !pip install -q langgraph langchain langchain-openai

# ============================================================
# IMPORTS
# ============================================================

import os
import json

from typing import TypedDict, Annotated

from google.colab import userdata

from langchain_openai import ChatOpenAI

from langchain_core.messages import (
    HumanMessage,
    SystemMessage
)

from langgraph.graph import (
    StateGraph,
    START,
    END
)

from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode

# ============================================================
# OPENAI KEY
# ============================================================

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# ============================================================
# LOGGER UTILITIES
# ============================================================

WIDTH = 90

def divider():
    print("═" * WIDTH)

def big_section(title):

    print("\n")
    divider()
    print(f" {title}")
    divider()

def sub_section(title):

    print(f"\n▶ {title}")
    print("─" * WIDTH)

def success(msg):
    print(f"✅ {msg}")

def warning(msg):
    print(f"⚠️  {msg}")

def info(msg):
    print(f"ℹ️  {msg}")

def tool_log(msg):
    print(f"🛠️  {msg}")

def route_log(msg):
    print(f"🧭 {msg}")

def agent_log(msg):
    print(f"🤖 {msg}")

def llm_log(msg):
    print(f"🧠 {msg}")

def pretty_json(data):

    print(json.dumps(data, indent=4))

# ============================================================
# INITIALIZE LLM
# ============================================================

big_section("INITIALIZING LLM")

MODEL_NAME = "gpt-4o-mini"

info(f"Selected Model: {MODEL_NAME}")

base_llm = ChatOpenAI(
    model=MODEL_NAME,
    temperature=0
)

success("LLM Initialized Successfully")

# ============================================================
# TOOLS
# ============================================================

big_section("REGISTERING TOOLS")

def lookup_invoice(customer_id: str):
    """
    Lookup telecom invoice details.
    """

    big_section("TOOL EXECUTION")

    tool_log("lookup_invoice() called")

    sub_section("INPUT")

    print(customer_id)

    result = {
        "customer_id": customer_id,
        "invoice_amount": 1299,
        "status": "PENDING"
    }

    sub_section("OUTPUT")

    pretty_json(result)

    return result


def process_payment(amount: int):
    """
    Process telecom payment.
    """

    big_section("TOOL EXECUTION")

    tool_log("process_payment() called")

    sub_section("INPUT")

    print(amount)

    result = {
        "payment_status": "SUCCESS",
        "amount_paid": amount
    }

    sub_section("OUTPUT")

    pretty_json(result)

    return result


def run_network_diagnostic():
    """
    Run telecom network diagnostics.
    """

    big_section("TOOL EXECUTION")

    tool_log("run_network_diagnostic() called")

    result = {
        "signal_strength": "WEAK",
        "tower_status": "ACTIVE",
        "issue_found": True
    }

    sub_section("OUTPUT")

    pretty_json(result)

    return result


def check_tower_status(location: str):
    """
    Check telecom tower health status.
    """

    big_section("TOOL EXECUTION")

    tool_log("check_tower_status() called")

    sub_section("INPUT")

    print(location)

    result = {
        "location": location,
        "tower_status": "HEALTHY"
    }

    sub_section("OUTPUT")

    pretty_json(result)

    return result

# ============================================================
# TOOL GROUPS
# ============================================================

BILLING_TOOLS = [
    lookup_invoice,
    process_payment
]

TECH_TOOLS = [
    run_network_diagnostic,
    check_tower_status
]

ALL_TOOLS = BILLING_TOOLS + TECH_TOOLS

sub_section("Billing Tools")

for tool in BILLING_TOOLS:

    print(f"• {tool.__name__}")

sub_section("Technical Tools")

for tool in TECH_TOOLS:

    print(f"• {tool.__name__}")

# ============================================================
# BIND TOOLS
# ============================================================

big_section("BINDING TOOLS TO LLM")

billing_llm = base_llm.bind_tools(BILLING_TOOLS)

tech_llm = base_llm.bind_tools(TECH_TOOLS)

success("Tools Bound Successfully")

# ============================================================
# STATE
# ============================================================

class TelecomState(TypedDict):

    messages: Annotated[list, add_messages]

    current_agent: str

# ============================================================
# SYSTEM PROMPTS
# ============================================================

billing_prompt = """
You are Rajan, Telecom Billing Specialist.

Responsibilities:
- Billing support
- Invoice support
- Payment issues

Rules:
- Always lookup invoice first
- Confirm invoice before payment
"""

tech_prompt = """
You are Priya, Telecom Technical Engineer.

Responsibilities:
- Slow internet
- Network issues
- Tower issues

Rules:
- Always run diagnostics first
"""

# ============================================================
# DISPLAY MESSAGES
# ============================================================

def display_messages(messages):

    big_section("WHAT LLM IS SEEING")

    for idx, msg in enumerate(messages):

        sub_section(f"MESSAGE {idx+1}")

        print(f"TYPE: {type(msg).__name__}")

        if hasattr(msg, "content"):

            print("\nCONTENT:\n")

            print(msg.content)

        if hasattr(msg, "tool_calls"):

            print("\nTOOL CALLS:\n")

            print(msg.tool_calls)

# ============================================================
# BILLING NODE
# ============================================================

def billing_node(state):

    big_section("ENTERING BILLING NODE")

    agent_log("Agent: Rajan")

    messages = [
        SystemMessage(content=billing_prompt)
    ] + state["messages"]

    display_messages(messages)

    big_section("CALLING BILLING LLM")

    llm_log("Invoking GPT-4o-mini")

    response = billing_llm.invoke(messages)

    sub_section("RAW LLM RESPONSE")

    print(response)

    sub_section("TOOL DECISION")

    if response.tool_calls:

        success("LLM Decided To Use Tool")

        for tool_call in response.tool_calls:

            tool_log(f"Selected Tool: {tool_call['name']}")

            info(f"Arguments: {tool_call['args']}")

    else:

        warning("No Tool Was Called")

    return {
        "messages": [response],
        "current_agent": "billing"
    }

# ============================================================
# TECH NODE
# ============================================================

def tech_node(state):

    big_section("ENTERING TECH NODE")

    agent_log("Agent: Priya")

    messages = [
        SystemMessage(content=tech_prompt)
    ] + state["messages"]

    display_messages(messages)

    big_section("CALLING TECH LLM")

    llm_log("Invoking GPT-4o-mini")

    response = tech_llm.invoke(messages)

    sub_section("RAW LLM RESPONSE")

    print(response)

    sub_section("TOOL DECISION")

    if response.tool_calls:

        success("LLM Decided To Use Tool")

        for tool_call in response.tool_calls:

            tool_log(f"Selected Tool: {tool_call['name']}")

            info(f"Arguments: {tool_call['args']}")

    else:

        warning("No Tool Was Called")

    return {
        "messages": [response],
        "current_agent": "tech"
    }

# ============================================================
# MAIN ROUTER
# ============================================================

def router(state):

    big_section("ROUTER EXECUTION")

    last_message = state["messages"][-1]

    user_text = last_message.content.lower()

    sub_section("USER QUERY")

    print(user_text)

    # ========================================================
    # BILLING ROUTE
    # ========================================================

    if any(word in user_text for word in [
        "bill",
        "invoice",
        "payment"
    ]):

        route_log("Routing To BILLING Agent")

        return "billing"

    # ========================================================
    # TECH ROUTE
    # ========================================================

    elif any(word in user_text for word in [
        "internet",
        "network",
        "slow",
        "wifi"
    ]):

        route_log("Routing To TECH Agent")

        return "tech"

    # ========================================================
    # DEFAULT
    # ========================================================

    route_log("Default Route -> TECH")

    return "tech"

# ============================================================
# TOOL ROUTER
# ============================================================

def tool_router(state):

    big_section("CHECKING TOOL CALLS")

    last_message = state["messages"][-1]

    if hasattr(last_message, "tool_calls") and last_message.tool_calls:

        success("Tool Call Detected")

        for tool_call in last_message.tool_calls:

            tool_log(f"Tool Selected: {tool_call['name']}")

            info(f"Arguments: {tool_call['args']}")

        return "tools"

    warning("No Tool Calls Found")

    return END

# ============================================================
# AFTER TOOL EXECUTION
# ============================================================

def after_tool_execution(state):

    big_section("RETURNING AFTER TOOL EXECUTION")

    current_agent = state["current_agent"]

    agent_log(f"Returning To: {current_agent}")

    return current_agent

# ============================================================
# TOOL NODE
# ============================================================

big_section("CREATING TOOL NODE")

tool_node = ToolNode(ALL_TOOLS)

success("Tool Node Created")

# ============================================================
# BUILD GRAPH
# ============================================================

big_section("BUILDING LANGGRAPH")

builder = StateGraph(TelecomState)

# ============================================================
# ADD NODES
# ============================================================

builder.add_node(
    "billing",
    billing_node
)

builder.add_node(
    "tech",
    tech_node
)

builder.add_node(
    "tools",
    tool_node
)

success("Nodes Added")

# ============================================================
# ENTRY ROUTING
# ============================================================

builder.add_conditional_edges(
    START,
    router,
    {
        "billing": "billing",
        "tech": "tech"
    }
)

# ============================================================
# BILLING -> TOOLS
# ============================================================

builder.add_conditional_edges(
    "billing",
    tool_router,
    {
        "tools": "tools",
        END: END
    }
)

# ============================================================
# TECH -> TOOLS
# ============================================================

builder.add_conditional_edges(
    "tech",
    tool_router,
    {
        "tools": "tools",
        END: END
    }
)

# ============================================================
# TOOLS -> AGENT
# ============================================================

builder.add_conditional_edges(
    "tools",
    after_tool_execution,
    {
        "billing": "billing",
        "tech": "tech"
    }
)

success("Graph Routes Connected")

# ============================================================
# COMPILE GRAPH
# ============================================================

big_section("COMPILING GRAPH")

graph = builder.compile()

success("Graph Compiled Successfully")

# ============================================================
# TEST QUERY
# ============================================================

big_section("USER QUERY")

query = "My internet is very slow"

print(query)

# ============================================================
# EXECUTE GRAPH
# ============================================================

big_section("STARTING GRAPH EXECUTION")

result = graph.invoke({
    "messages": [
        HumanMessage(content=query)
    ]
})

# ============================================================
# FINAL OUTPUT
# ============================================================

big_section("FINAL GRAPH OUTPUT")

for idx, msg in enumerate(result["messages"]):

    sub_section(f"FINAL MESSAGE {idx+1}")

    print(f"TYPE: {type(msg).__name__}")

    if hasattr(msg, "content"):

        print("\nCONTENT:\n")

        print(msg.content)

    if hasattr(msg, "tool_calls"):

        print("\nTOOL CALLS:\n")

        print(msg.tool_calls)

success("Execution Completed Successfully")
# Out:
# ══════════════════════════════════════════════════════════════════════════════════════════
#  INITIALIZING LLM
# ══════════════════════════════════════════════════════════════════════════════════════════
# ℹ️  Selected Model: gpt-4o-mini
# ✅ LLM Initialized Successfully
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  REGISTERING TOOLS
# ══════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ Billing Tools
# ──────────────────────────────────────────────────────────────────────────────────────────
# • lookup_invoice
# • process_payment
#
# ▶ Technical Tools
# ──────────────────────────────────────────────────────────────────────────────────────────
# • run_network_diagnostic
# • check_tower_status
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  BINDING TOOLS TO LLM
# ══════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tools Bound Successfully
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  CREATING TOOL NODE
# ══════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Node Created
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  BUILDING LANGGRAPH
# ══════════════════════════════════════════════════════════════════════════════════════════
# ✅ Nodes Added
# ✅ Graph Routes Connected
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  COMPILING GRAPH
# ══════════════════════════════════════════════════════════════════════════════════════════
# ✅ Graph Compiled Successfully
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  USER QUERY
# ══════════════════════════════════════════════════════════════════════════════════════════
# My internet is very slow
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  STARTING GRAPH EXECUTION
# ══════════════════════════════════════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  ROUTER EXECUTION
# ══════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ USER QUERY
# ──────────────────────────────────────────────────────────────────────────────────────────
# my internet is very slow
# 🧭 Routing To TECH Agent
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  ENTERING TECH NODE
# ══════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ══════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Engineer.
#
# Responsibilities:
# - Slow internet
# - Network issues
# - Tower issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
# My internet is very slow
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  CALLING TECH LLM
# ══════════════════════════════════════════════════════════════════════════════════════════
# 🧠 Invoking GPT-4o-mini
#
# ▶ RAW LLM RESPONSE
# ──────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 97, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f26e464023', 'id': 'chatcmpl-E09m7Kw4Y0XIucpael9WVjGeLtBkE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d2d-eaf1-7fe1-85da-9f14cd62599a-0' tool_calls=[{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_luysUeW5UJLmT9uL5pguUEFB', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 97, 'output_tokens': 12, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ──────────────────────────────────────────────────────────────────────────────────────────
# ✅ LLM Decided To Use Tool
# 🛠️  Selected Tool: run_network_diagnostic
# ℹ️  Arguments: {}
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ══════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ══════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic() called
#
# ▶ OUTPUT
# ──────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  RETURNING AFTER TOOL EXECUTION
# ══════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Returning To: tech
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  ENTERING TECH NODE
# ══════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ══════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Engineer.
#
# Responsibilities:
# - Slow internet
# - Network issues
# - Tower issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
# My internet is very slow
#
# ▶ MESSAGE 3
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_luysUeW5UJLmT9uL5pguUEFB', 'type': 'tool_call'}]
#
# ▶ MESSAGE 4
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {"signal_strength": "WEAK", "tower_status": "ACTIVE", "issue_found": true}
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  CALLING TECH LLM
# ══════════════════════════════════════════════════════════════════════════════════════════
# 🧠 Invoking GPT-4o-mini
#
# ▶ RAW LLM RESPONSE
# ──────────────────────────────────────────────────────────────────────────────────────────
# content='The diagnostics indicate that your internet issue is due to weak signal strength. The tower status is active, but there is an issue affecting your connection. \n\nWould you like me to check the health status of the nearest tower to your location?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 140, 'total_tokens': 188, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f26e464023', 'id': 'chatcmpl-E09m8k8DJFoXatScTcqYCBJAbFAFI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d2d-eecd-7f43-bd86-89ff36740bec-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 140, 'output_tokens': 48, 'total_tokens': 188, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ──────────────────────────────────────────────────────────────────────────────────────────
# ⚠️  No Tool Was Called
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ══════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#  FINAL GRAPH OUTPUT
# ══════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ FINAL MESSAGE 1
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
# My internet is very slow
#
# ▶ FINAL MESSAGE 2
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_luysUeW5UJLmT9uL5pguUEFB', 'type': 'tool_call'}]
#
# ▶ FINAL MESSAGE 3
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {"signal_strength": "WEAK", "tower_status": "ACTIVE", "issue_found": true}
#
# ▶ FINAL MESSAGE 4
# ──────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
# The diagnostics indicate that your internet issue is due to weak signal strength. The tower status is active, but there is an issue affecting your connection.
#
# Would you like me to check the health status of the nearest tower to your location?
#
# TOOL CALLS:
#
# []
# ✅ Execution Completed Successfully

# %%
# ============================================================
# PARALLEL MULTI AGENT SYSTEM
# WITH:
# ✅ Parallel Agent Execution
# ✅ Combined Responses
# ✅ Beautiful Structured Logs
# ✅ Execution Time Tracking
# ✅ Tool Calling Visibility
# ✅ ToolNode Visibility
# ============================================================

# ============================================================
# INSTALL
# ============================================================

# !pip install -q langgraph langchain langchain-openai

# ============================================================
# IMPORTS
# ============================================================

import os
import json
import time

from datetime import datetime

from typing import TypedDict, Annotated

from google.colab import userdata

from langchain_openai import ChatOpenAI

from langchain_core.messages import (
    HumanMessage,
    SystemMessage
)

from langgraph.graph import (
    StateGraph,
    START,
    END
)

from langgraph.graph.message import add_messages

from langgraph.prebuilt import ToolNode

from langchain_core.tools import tool

from langgraph.types import Command

# ============================================================
# OPENAI KEY
# ============================================================

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# ============================================================
# LOGGER UTILITIES
# ============================================================

WIDTH = 100

def divider():
    print("═" * WIDTH)

def big_section(title):

    print("\n")
    divider()
    print(f" {title}")
    divider()

def sub_section(title):

    print(f"\n▶ {title}")
    print("─" * WIDTH)

def success(msg):
    print(f"✅ {msg}")

def warning(msg):
    print(f"⚠️  {msg}")

def info(msg):
    print(f"ℹ️  {msg}")

def tool_log(msg):
    print(f"🛠️  {msg}")

def route_log(msg):
    print(f"🧭 {msg}")

def agent_log(msg):
    print(f"🤖 {msg}")

def llm_log(msg):
    print(f"🧠 {msg}")

def timer_log(start):

    elapsed = round(time.time() - start, 2)

    print(f"⏱️  Execution Time: {elapsed} sec")

def pretty_json(data):

    print(json.dumps(data, indent=4))

# ============================================================
# LLM
# ============================================================

big_section("INITIALIZING LLM")

MODEL_NAME = "gpt-4o-mini"

info(f"Model: {MODEL_NAME}")

base_llm = ChatOpenAI(
    model=MODEL_NAME,
    temperature=0
)

success("LLM Initialized")

# ============================================================
# TOOLS
# ============================================================

big_section("REGISTERING TOOLS")


def lookup_invoice(customer_id: str):
    """
    Lookup telecom invoice details.
    """

    start = time.time()

    big_section("TOOL EXECUTION")

    tool_log("lookup_invoice()")

    sub_section("INPUT")

    print(customer_id)

    result = {
        "customer_id": customer_id,
        "invoice_amount": 1299,
        "status": "PENDING"
    }

    sub_section("OUTPUT")

    pretty_json(result)

    timer_log(start)

    return result


def run_network_diagnostic():
    """
    Run telecom network diagnostics.
    """

    start = time.time()

    big_section("TOOL EXECUTION")

    tool_log("run_network_diagnostic()")

    result = {
        "signal_strength": "WEAK",
        "tower_status": "ACTIVE",
        "issue_found": True
    }

    sub_section("OUTPUT")

    pretty_json(result)

    timer_log(start)

    return result

# ============================================================
# TOOL GROUPS
# ============================================================

BILLING_TOOLS = [
    lookup_invoice
]

TECH_TOOLS = [
    run_network_diagnostic
]

ALL_TOOLS = BILLING_TOOLS + TECH_TOOLS
TOOLS = [lookup_invoice, run_network_diagnostic]
TOOL_MAP = {tool.__name__: tool for tool in TOOLS}

sub_section("Billing Tools")

for tool in BILLING_TOOLS:
    print(f"• {tool.__name__}")

sub_section("Tech Tools")

for tool in TECH_TOOLS:
    print(f"• {tool.__name__}")

# ============================================================
# BIND TOOLS
# ============================================================

big_section("BINDING TOOLS")

billing_llm = base_llm.bind_tools(BILLING_TOOLS)

tech_llm = base_llm.bind_tools(TECH_TOOLS)

success("Tools Bound Successfully")

# ============================================================
# STATE
# ============================================================

class TelecomState(TypedDict):

    messages: Annotated[list, add_messages]
    messages_billing: Annotated[list, add_messages]
    messages_tech: Annotated[list, add_messages]

    billing_response: str

    tech_response: str

    billing_complete: bool
    tech_complete: bool

    # current_agent: str

    # current_agent: Annotated[list, add_messages]

# ============================================================
# SYSTEM PROMPTS
# ============================================================

billing_prompt = """
You are Rajan, Telecom Billing Agent.

Responsibilities:
- Invoice support
- Billing issues

Rules:
- Always lookup invoice first
"""

tech_prompt = """
You are Priya, Telecom Technical Agent.

Responsibilities:
- Slow internet
- Network issues

Rules:
- Always run diagnostics first
"""

combiner_prompt = """
You are Nova, Final Response Combiner Agent.

Responsibilities:
- Combine multiple agent outputs
- Generate final professional response
"""

# ============================================================
# DISPLAY MESSAGES
# ============================================================

def display_messages(messages):

    big_section("WHAT LLM IS SEEING")

    for idx, msg in enumerate(messages):

        sub_section(f"MESSAGE {idx+1}")

        print(f"TYPE: {type(msg).__name__}")

        if hasattr(msg, "content"):

            print("\nCONTENT:\n")

            print(msg.content)

        if hasattr(msg, "tool_calls"):

            print("\nTOOL CALLS:\n")

            print(msg.tool_calls)

# ============================================================
# BILLING NODE
# ============================================================

def billing_node(state):

    start = time.time()

    billing_complete = False

    big_section("BILLING AGENT STARTED")

    agent_log("Agent: Rajan")

    if not state["messages_billing"]:
       state["messages_billing"] = state["messages"]

    messages = [
        SystemMessage(content=billing_prompt)
    ] + state["messages_billing"]

    display_messages(messages)

    llm_log("Calling Billing LLM")

    response = billing_llm.invoke(messages)

    sub_section("RAW LLM RESPONSE")

    print(response)

    if response.tool_calls:

        sub_section("TOOL DECISION")

        for tc in response.tool_calls:

            tool_log(f"Tool Selected: {tc['name']}")

            info(f"Arguments: {tc['args']}")

    if response.content:
       billing_complete = True

    timer_log(start)

    return {
        "messages_billing": [response],
        "billing_response": str(response.content),
        #"billing_complete": True
        "billing_complete": billing_complete

    }

# ============================================================
# TECH NODE
# ============================================================

def tech_node(state):

    start = time.time()

    tech_complete = False

    big_section("TECH AGENT STARTED")

    agent_log("Agent: Priya")

    if not state["messages_tech"]:
       state["messages_tech"] = state["messages"]

    messages = [
        SystemMessage(content=tech_prompt)
    ] + state["messages_tech"]

    display_messages(messages)

    llm_log("Calling Tech LLM")

    response = tech_llm.invoke(messages)

    sub_section("RAW LLM RESPONSE")

    print(response)

    if response.tool_calls:

        sub_section("TOOL DECISION")

        for tc in response.tool_calls:

            tool_log(f"Tool Selected: {tc['name']}")

            info(f"Arguments: {tc['args']}")

    if response.content:
       tech_complete = True

    timer_log(start)

    return {
        "messages_tech": [response],
        "tech_response": str(response.content),
        #"tech_complete": True
        "tech_complete": tech_complete
    }

# ============================================================
# CUSTOM TOOL NODE
# ============================================================

class DebugToolNode(ToolNode):

    def invoke(self, state, config=None):

        start = time.time()

        big_section("TOOL NODE EXECUTION")

        if state["current_agent"][-1].content == "billing":
           last_message = state["messages_billing"][-1]

        if state["current_agent"][-1].content == "tech":
           last_message = state["messages_tech"][-1]

        sub_section("TOOL CALLS RECEIVED")

        print(last_message.tool_calls)

        result = super().invoke(state, config)

        sub_section("TOOL NODE OUTPUT")

        print(result)

        timer_log(start)

        return result

# ============================================================
# COMBINER NODE
# ============================================================

def combiner_node(state):

    start = time.time()

    big_section("COMBINER AGENT")

    billing_output = state.get("billing_response", "")

    tech_output = state.get("tech_response", "")

    sub_section("AGENT OUTPUTS")

    print("\nBILLING OUTPUT:\n")
    print(billing_output)

    print("\nTECH OUTPUT:\n")
    print(tech_output)

    final_prompt = f"""
{combiner_prompt}

Billing Agent Output:
{billing_output}

Tech Agent Output:
{tech_output}

Generate one final customer response.
"""

    llm_log("Combining Agent Outputs")

    response = base_llm.invoke(final_prompt)

    sub_section("FINAL COMBINED RESPONSE")

    print(response.content)

    timer_log(start)

    return {
        "messages": [response]
    }

# ============================================================
# TOOL ROUTER
# ============================================================

def tool_combiner_router_billing(state):

    big_section("CHECKING TOOL CALLS")



    last_message = state["messages_billing"][-1]




    if hasattr(last_message, "tool_calls") and last_message.tool_calls:

        success("Tool Call Detected")

        for tool_call in last_message.tool_calls:

            tool_log(f"Tool Selected: {tool_call['name']}")

            info(f"Arguments: {tool_call['args']}")

        return "tools"

    warning("No Tool Calls Found")



    # return "combiner"
    return "join"

def tool_combiner_router_tech(state):

    big_section("CHECKING TOOL CALLS")



    last_message = state["messages_tech"][-1]




    if hasattr(last_message, "tool_calls") and last_message.tool_calls:

        success("Tool Call Detected")

        for tool_call in last_message.tool_calls:

            tool_log(f"Tool Selected: {tool_call['name']}")

            info(f"Arguments: {tool_call['args']}")

        return "tools"

    warning("No Tool Calls Found")


    # return "combiner"
    return "join"

# ============================================================
# AFTER TOOL EXECUTION
# ============================================================

def after_tool_execution(state):

    big_section("RETURNING AFTER TOOL EXECUTION")

    current_agent = state["current_agent"][-1].content
    # current_agent = state["current_agent"]

    agent_log(f"Returning To: {current_agent}")

    return current_agent




# ============================================================
# TOOL NODE
# ============================================================

# tool_node = DebugToolNode(ALL_TOOLS)
# tool_node = ToolNode(ALL_TOOLS)

def billing_tool_node(state):


    last_message = state["messages_billing"][-1]


    tool_messages = []

    for tool_call in last_message.tool_calls:

        tool_name = tool_call["name"]
        tool_args = tool_call["args"]

        try:
            result = TOOL_MAP[tool_name](**tool_args)

        except Exception as e:
            result = f"Tool Error: {e}"

        tool_messages.append(
            ToolMessage(
                content=str(result),
                tool_call_id=tool_call["id"],
            )
        )



    return {
        "messages_billing": tool_messages
           }



def tech_tool_node(state):



    last_message = state["messages_tech"][-1]


    tool_messages = []

    for tool_call in last_message.tool_calls:

        tool_name = tool_call["name"]
        tool_args = tool_call["args"]

        try:
            result = TOOL_MAP[tool_name](**tool_args)

        except Exception as e:
            result = f"Tool Error: {e}"

        tool_messages.append(
            ToolMessage(
                content=str(result),
                tool_call_id=tool_call["id"],
            )
        )



    return {
           "messages_tech": tool_messages
           }

def join(state):

    if state["billing_complete"] and state["tech_complete"]:
        return Command(goto="combiner")

    return Command(goto=END)

# ============================================================
# BUILD GRAPH
# ============================================================

big_section("BUILDING GRAPH")

builder = StateGraph(TelecomState)

# ============================================================
# ADD NODES
# ============================================================

builder.add_node("billing", billing_node)

builder.add_node("tech", tech_node)

builder.add_node("billing_tools", billing_tool_node)

builder.add_node("tech_tools", tech_tool_node)

builder.add_node("combiner", combiner_node)

builder.add_node("join", join)

success("Nodes Added")

# ============================================================
# PARALLEL EXECUTION
# ============================================================

builder.add_edge(START, "billing")

builder.add_edge(START, "tech")

# ============================================================
# BOTH GO TO COMBINER
# ============================================================

# builder.add_edge("billing", "combiner")

# builder.add_edge("tech", "combiner")

builder.add_conditional_edges(
    "billing",
    tool_combiner_router_billing,
    {
        "tools": "billing_tools",
        #"combiner": "combiner"
        "join": "join"
    }
)

builder.add_conditional_edges(
    "tech",
    tool_combiner_router_tech,
    {
        "tools": "tech_tools",
        #"combiner": "combiner"
        "join": "join"
    }
)

'''
builder.add_conditional_edges(
    "tools",
    after_tool_execution,
    {
        "billing": "billing",
        "tech": "tech"
    }
)
'''

builder.add_edge("billing_tools", "billing")
builder.add_edge("tech_tools", "tech")

# ============================================================
# END
# ============================================================

builder.add_edge("combiner", END)

# ============================================================
# COMPILE
# ============================================================

graph = builder.compile()

success("Graph Compiled Successfully")

# ============================================================
# TEST QUERY
# ============================================================

query = """
My internet is slow and I also want to check my invoice. My Custmer Id is C001.
"""

big_section("USER QUERY")

print(query)

# ============================================================
# EXECUTION
# ============================================================

global_start = time.time()

big_section("STARTING GRAPH EXECUTION")

result = graph.invoke({
    "messages": [
        HumanMessage(content=query)
    ]
})

# ============================================================
# FINAL OUTPUT
# ============================================================

big_section("FINAL OUTPUT")

for idx, msg in enumerate(result["messages"]):

    sub_section(f"MESSAGE {idx+1}")

    print(type(msg).__name__)

    if hasattr(msg, "content"):

        print("\nCONTENT:\n")

        print(msg.content)

# ============================================================
# TOTAL EXECUTION TIME
# ============================================================

big_section("TOTAL EXECUTION TIME")

timer_log(global_start)

success("Execution Completed")
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  INITIALIZING LLM
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ℹ️  Model: gpt-4o-mini
# ✅ LLM Initialized
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  REGISTERING TOOLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ Billing Tools
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# • lookup_invoice
#
# ▶ Tech Tools
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# • run_network_diagnostic
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BINDING TOOLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tools Bound Successfully
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BUILDING GRAPH
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Nodes Added
# ✅ Graph Compiled Successfully
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  USER QUERY
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# My internet is slow and I also want to check my invoice. My Custmer Id is C001.
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  STARTING GRAPH EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
# My internet is slow and I also want to check my invoice. My Custmer Id is C001.
#
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
# My internet is slow and I also want to check my invoice. My Custmer Id is C001.
#
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 93, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0ADOWyIutZiIbc4SYJsuGIehVi36', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d47-b4cb-75c3-957b-56a0e9ab61a7-0' tool_calls=[{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_5JKNil8yPGGvFvRtzMdFJD6j', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 93, 'output_tokens': 16, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
# ⏱️  Execution Time: 1.81 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 88, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0ADOWwIGBcoMUjZbxRb4sdNe3ZsY', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d47-b4cf-7003-a6c9-dd874862710b-0' tool_calls=[{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_NYjw9E9qfD6WofIjKGfEzdVE', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 88, 'output_tokens': 12, 'total_tokens': 100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# ⏱️  Execution Time: 1.85 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  lookup_invoice()
#
# ▶ INPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# C001
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "customer_id": "C001",
#     "invoice_amount": 1299,
#     "status": "PENDING"
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_5JKNil8yPGGvFvRtzMdFJD6j', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'customer_id': 'C001', 'invoice_amount': 1299, 'status': 'PENDING'}
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_NYjw9E9qfD6WofIjKGfEzdVE', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'signal_strength': 'WEAK', 'tower_status': 'ACTIVE', 'issue_found': True}
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The diagnostics indicate that there is a weak signal strength, and an issue has been found. The tower status is active, but the weak signal could be causing your slow internet and network issues. \n\nWould you like assistance with troubleshooting this issue further?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 105, 'total_tokens': 155, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0ADOvuExgJuqZTqT14uVTPm8ovKo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d47-bc14-7fa2-b491-803c02f1fa21-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 105, 'output_tokens': 50, 'total_tokens': 155, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 0.95 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The invoice details for customer ID C001 are as follows:\n\n- **Invoice Amount:** $1299\n- **Status:** PENDING\n\nIf you have any specific questions or need further assistance regarding this invoice, please let me know!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 114, 'total_tokens': 162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0ADPbq5dxfHqUcw990hw4wxOyBDg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d47-bc11-7173-a2ab-c787ccd7457c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 114, 'output_tokens': 48, 'total_tokens': 162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.27 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  COMBINER AGENT
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ AGENT OUTPUTS
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BILLING OUTPUT:
#
# The invoice details for customer ID C001 are as follows:
#
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or need further assistance regarding this invoice, please let me know!
#
# TECH OUTPUT:
#
# The diagnostics indicate that there is a weak signal strength, and an issue has been found. The tower status is active, but the weak signal could be causing your slow internet and network issues.
#
# Would you like assistance with troubleshooting this issue further?
# 🧠 Combining Agent Outputs
#
# ▶ FINAL COMBINED RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Subject: Invoice and Connectivity Update
#
# Dear Customer,
#
# Thank you for reaching out.
#
# Regarding your invoice for customer ID C001, the details are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any questions or need further assistance with this invoice, please let me know.
#
# Additionally, our diagnostics have identified a weak signal strength that may be contributing to your slow internet and network issues. While the tower status is active, this weak signal could be affecting your connectivity.
#
# Would you like assistance with troubleshooting this issue further?
#
# Please feel free to reach out with any questions or concerns.
#
# Best regards,
# [Your Name]
# [Your Position]
# [Your Contact Information]
# ⏱️  Execution Time: 2.07 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  FINAL OUTPUT
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# HumanMessage
#
# CONTENT:
#
#
# My internet is slow and I also want to check my invoice. My Custmer Id is C001.
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# AIMessage
#
# CONTENT:
#
# Subject: Invoice and Connectivity Update
#
# Dear Customer,
#
# Thank you for reaching out.
#
# Regarding your invoice for customer ID C001, the details are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any questions or need further assistance with this invoice, please let me know.
#
# Additionally, our diagnostics have identified a weak signal strength that may be contributing to your slow internet and network issues. While the tower status is active, this weak signal could be affecting your connectivity.
#
# Would you like assistance with troubleshooting this issue further?
#
# Please feel free to reach out with any questions or concerns.
#
# Best regards,
# [Your Name]
# [Your Position]
# [Your Contact Information]
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOTAL EXECUTION TIME
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⏱️  Execution Time: 5.21 sec
# ✅ Execution Completed

# %%
# ============================================================
# MULTIPLE TEST CASES
# ============================================================

test_queries = [

    # ========================================================
    # BOTH AGENTS SHOULD WORK IN PARALLEL
    # ========================================================

    """
    My internet is very slow and I also want to check my invoice. My Customer Id is C001.
    """,

    # ========================================================
    # BILLING FOCUSED
    # ========================================================

    """
    I want to verify my pending bill payment. My Customer Id is C001.
    """,

    # ========================================================
    # TECH FOCUSED
    # ========================================================

    """
    My WiFi is not working properly.
    """,

    # ========================================================
    # STRONG PARALLEL EXAMPLE
    # ========================================================

    """
    My network is unstable and I need invoice details for last month. My Customer Id is C001.
    """,

    # ========================================================
    # ANOTHER PARALLEL CASE
    # ========================================================

    """
    Internet speed is poor and payment confirmation is pending. My Customer Id is C001.
    """,

]

# ============================================================
# EXECUTE TESTS
# ============================================================

for idx, query in enumerate(test_queries):

    global_start = time.time()

    big_section(f"TEST CASE {idx+1}")

    print(query)

    big_section("GRAPH EXECUTION STARTED")

    result = graph.invoke({
        "messages": [
            HumanMessage(content=query)
        ]
    })

    # ========================================================
    # FINAL OUTPUT
    # ========================================================

    big_section("FINAL RESPONSE")

    for m in result["messages"]:

        if hasattr(m, "content"):

            print("\n")
            print(m.content)

    # ========================================================
    # TOTAL TIME
    # ========================================================

    big_section("TOTAL EXECUTION TIME")

    timer_log(global_start)

    print("\n\n")
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TEST CASE 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#     My internet is very slow and I also want to check my invoice. My Customer Id is C001.
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  GRAPH EXECUTION STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     My internet is very slow and I also want to check my invoice. My Customer Id is C001.
#
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     My internet is very slow and I also want to check my invoice. My Customer Id is C001.
#
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 90, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEGO1WDcEqBJdFctrBY3cLFOwGx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-8ed4-7882-a949-642bec2f8029-0' tool_calls=[{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_rtb2Zx7o0hLw0tcyUc0Cfutd', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 90, 'output_tokens': 12, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# ⏱️  Execution Time: 0.78 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 95, 'total_tokens': 111, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEGJdTJXQ4jKsaZjKMoBLEiYQQk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-8ed0-7f83-b2ef-2a18570158ee-0' tool_calls=[{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_r50hcQpYVb82JnwlOBCUzDuC', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 95, 'output_tokens': 16, 'total_tokens': 111, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
# ⏱️  Execution Time: 0.91 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  lookup_invoice()
#
# ▶ INPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# C001
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "customer_id": "C001",
#     "invoice_amount": 1299,
#     "status": "PENDING"
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_r50hcQpYVb82JnwlOBCUzDuC', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'customer_id': 'C001', 'invoice_amount': 1299, 'status': 'PENDING'}
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_rtb2Zx7o0hLw0tcyUc0Cfutd', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'signal_strength': 'WEAK', 'tower_status': 'ACTIVE', 'issue_found': True}
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The diagnostics indicate that there is a weak signal strength, and an issue has been found. The tower status is active, but the weak signal could be causing your slow internet. \n\nWould you like assistance with troubleshooting this issue further?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 105, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEHsppTUGRrtY6UzdeNI4PtOJlg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d48-9267-7142-9156-97d8a3802b5e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 105, 'output_tokens': 47, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.02 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The invoice details for customer ID C001 are as follows:\n- **Invoice Amount:** $1299\n- **Status:** PENDING\n\nIf you have any specific questions or issues regarding this invoice, please let me know!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 114, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEIU2tv1rb3u9HXyar7s1KrENEO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d48-9264-7143-8f60-60d3f229d068-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 114, 'output_tokens': 46, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.73 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  COMBINER AGENT
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ AGENT OUTPUTS
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BILLING OUTPUT:
#
# The invoice details for customer ID C001 are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or issues regarding this invoice, please let me know!
#
# TECH OUTPUT:
#
# The diagnostics indicate that there is a weak signal strength, and an issue has been found. The tower status is active, but the weak signal could be causing your slow internet.
#
# Would you like assistance with troubleshooting this issue further?
# 🧠 Combining Agent Outputs
#
# ▶ FINAL COMBINED RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Subject: Invoice and Connectivity Update
#
# Dear Customer,
#
# Thank you for reaching out.
#
# Regarding your invoice for customer ID C001, the details are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any questions or concerns about this invoice, please feel free to ask.
#
# Additionally, our diagnostics have detected a weak signal strength that may be affecting your internet speed. While the tower status is active, this issue could be the cause of your slow connectivity.
#
# If you would like assistance with troubleshooting this issue further, please let us know, and we will be happy to help.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# [Your Company]
# [Contact Information]
# ⏱️  Execution Time: 3.18 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  FINAL RESPONSE
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
#
#     My internet is very slow and I also want to check my invoice. My Customer Id is C001.
#
#
#
# Subject: Invoice and Connectivity Update
#
# Dear Customer,
#
# Thank you for reaching out.
#
# Regarding your invoice for customer ID C001, the details are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any questions or concerns about this invoice, please feel free to ask.
#
# Additionally, our diagnostics have detected a weak signal strength that may be affecting your internet speed. While the tower status is active, this issue could be the cause of your slow connectivity.
#
# If you would like assistance with troubleshooting this issue further, please let us know, and we will be happy to help.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# [Your Company]
# [Contact Information]
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOTAL EXECUTION TIME
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⏱️  Execution Time: 5.83 sec
#
#
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TEST CASE 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#     I want to verify my pending bill payment. My Customer Id is C001.
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  GRAPH EXECUTION STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     I want to verify my pending bill payment. My Customer Id is C001.
#
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     I want to verify my pending bill payment. My Customer Id is C001.
#
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 90, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEMCXNDhuG9PdC99Pj30C1zAy95', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-a592-7682-87d3-60f662850bb5-0' tool_calls=[{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_0JWIYigZkfU6fVSq085nTtWq', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 90, 'output_tokens': 16, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
# ⏱️  Execution Time: 0.83 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content="I can help you with network issues and slow internet, but I don't have access to billing information. Please check your service provider's website or contact their customer service for assistance with your pending bill payment. If you have any network-related issues, feel free to let me know!" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 85, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEMQhTcq6gOEmHkqRMLig0i7W9V', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d48-a595-7513-aba6-eb699e4ba259-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 85, 'output_tokens': 56, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.29 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  lookup_invoice()
#
# ▶ INPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# C001
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "customer_id": "C001",
#     "invoice_amount": 1299,
#     "status": "PENDING"
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_0JWIYigZkfU6fVSq085nTtWq', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'customer_id': 'C001', 'invoice_amount': 1299, 'status': 'PENDING'}
# 🧠 Calling Billing LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The invoice details for customer ID C001 are as follows:\n- **Invoice Amount:** $1299\n- **Status:** PENDING\n\nIf you have any specific questions or issues regarding this invoice, please let me know!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 114, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEOkOVUhVw0la55R7uEJWm1sQ2q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d48-aa9e-71e2-ac44-f6e8ca762944-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 114, 'output_tokens': 46, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.18 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  COMBINER AGENT
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ AGENT OUTPUTS
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BILLING OUTPUT:
#
# The invoice details for customer ID C001 are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or issues regarding this invoice, please let me know!
#
# TECH OUTPUT:
#
# I can help you with network issues and slow internet, but I don't have access to billing information. Please check your service provider's website or contact their customer service for assistance with your pending bill payment. If you have any network-related issues, feel free to let me know!
# 🧠 Combining Agent Outputs
#
# ▶ FINAL COMBINED RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Dear Customer,
#
# Thank you for reaching out.
#
# Regarding your invoice for customer ID C001, the details are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or issues related to this invoice, please let me know, and I will be happy to assist you further.
#
# For any inquiries related to network issues or slow internet, please feel free to reach out. However, please note that I do not have access to billing information, so for assistance with your pending bill payment, I recommend checking your service provider's website or contacting their customer service directly.
#
# Thank you for your understanding!
#
# Best regards,
# [Your Name]
# [Your Position]
# ⏱️  Execution Time: 4.91 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  FINAL RESPONSE
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
#
#     I want to verify my pending bill payment. My Customer Id is C001.
#
#
#
# Dear Customer,
#
# Thank you for reaching out.
#
# Regarding your invoice for customer ID C001, the details are as follows:
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or issues related to this invoice, please let me know, and I will be happy to assist you further.
#
# For any inquiries related to network issues or slow internet, please feel free to reach out. However, please note that I do not have access to billing information, so for assistance with your pending bill payment, I recommend checking your service provider's website or contacting their customer service directly.
#
# Thank you for your understanding!
#
# Best regards,
# [Your Name]
# [Your Position]
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOTAL EXECUTION TIME
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⏱️  Execution Time: 7.38 sec
#
#
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TEST CASE 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#     My WiFi is not working properly.
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  GRAPH EXECUTION STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     My WiFi is not working properly.
#
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     My WiFi is not working properly.
#
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 77, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEUeglOhuFQBty0edNaMpHRystx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-c26c-7a32-b10b-f64ac011aebe-0' tool_calls=[{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_0tWNUYGuPDU9cuAI8X2565Zt', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 77, 'output_tokens': 12, 'total_tokens': 89, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# ⏱️  Execution Time: 0.86 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content="I can help you with billing issues or invoice support. If you're experiencing problems with your WiFi, it might be best to contact technical support for assistance. However, if you have any billing-related questions or need to check your invoice, please provide your customer ID, and I'll look it up for you." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 82, 'total_tokens': 144, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEURcQpIt9o8wKsN4BohsafeAw9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d48-c269-7b83-8b3e-e0f05588a3e9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 82, 'output_tokens': 62, 'total_tokens': 144, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.3 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_0tWNUYGuPDU9cuAI8X2565Zt', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'signal_strength': 'WEAK', 'tower_status': 'ACTIVE', 'issue_found': True}
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The diagnostics indicate that there is a weak signal strength, and an issue has been found. The tower status is active, which means the tower is operational. \n\nWould you like assistance with troubleshooting the weak signal issue?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 105, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEWcmbIkQALwIPog5rgNHE0WPuP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d48-c77c-7ef1-9d55-a85417482a83-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 105, 'output_tokens': 44, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 2.37 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  COMBINER AGENT
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ AGENT OUTPUTS
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BILLING OUTPUT:
#
# I can help you with billing issues or invoice support. If you're experiencing problems with your WiFi, it might be best to contact technical support for assistance. However, if you have any billing-related questions or need to check your invoice, please provide your customer ID, and I'll look it up for you.
#
# TECH OUTPUT:
#
# The diagnostics indicate that there is a weak signal strength, and an issue has been found. The tower status is active, which means the tower is operational.
#
# Would you like assistance with troubleshooting the weak signal issue?
# 🧠 Combining Agent Outputs
#
# ▶ FINAL COMBINED RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Thank you for reaching out. It seems that you are experiencing a weak signal issue with your WiFi. While our technical diagnostics show that the tower is operational, I recommend contacting technical support for further assistance with troubleshooting this problem.
#
# If you have any billing-related questions or need help with your invoice, please provide your customer ID, and I will be happy to assist you with that as well. Let me know how you would like to proceed!
# ⏱️  Execution Time: 1.59 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  FINAL RESPONSE
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
#
#     My WiFi is not working properly.
#
#
#
# Thank you for reaching out. It seems that you are experiencing a weak signal issue with your WiFi. While our technical diagnostics show that the tower is operational, I recommend contacting technical support for further assistance with troubleshooting this problem.
#
# If you have any billing-related questions or need help with your invoice, please provide your customer ID, and I will be happy to assist you with that as well. Let me know how you would like to proceed!
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOTAL EXECUTION TIME
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⏱️  Execution Time: 5.26 sec
#
#
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TEST CASE 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#     My network is unstable and I need invoice details for last month. My Customer Id is C001.
#
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  GRAPH EXECUTION STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     My network is unstable and I need invoice details for last month. My Customer Id is C001.
#
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     My network is unstable and I need invoice details for last month. My Customer Id is C001.
#
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 94, 'total_tokens': 110, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEZDJwnibUCJxIuRflE2URuplbE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-d6f7-7f51-a604-bfc2ee509e3c-0' tool_calls=[{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_3RilHt5MmPSYTsTX4D33iBfQ', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 94, 'output_tokens': 16, 'total_tokens': 110, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
# ⏱️  Execution Time: 1.15 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 89, 'total_tokens': 132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEZmjQSCijSfm6OmYygGKOnTv57', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-d6fb-7d51-9de6-51b566e5a25e-0' tool_calls=[{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_jUZriUPr6m11usTrPY3FPvSu', 'type': 'tool_call'}, {'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_GDdhFYVT4OFrIgejhqikHLKL', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 89, 'output_tokens': 43, 'total_tokens': 132, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# ⏱️  Execution Time: 1.33 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  lookup_invoice()
#
# ▶ INPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# C001
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "customer_id": "C001",
#     "invoice_amount": 1299,
#     "status": "PENDING"
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_3RilHt5MmPSYTsTX4D33iBfQ', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'customer_id': 'C001', 'invoice_amount': 1299, 'status': 'PENDING'}
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# ...
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     Internet speed is poor and payment confirmation is pending. My Customer Id is C001.
#
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: HumanMessage
#
# CONTENT:
#
#
#     Internet speed is poor and payment confirmation is pending. My Customer Id is C001.
#
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 86, 'total_tokens': 129, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEjz4unJXQzrYoNa60nzn0D0FYY', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-fdd1-7771-a117-997c97676d02-0' tool_calls=[{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_wF9neahVsQPzO6Mg4JPTpLj5', 'type': 'tool_call'}, {'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_hJ1dDQwzyxxbniEpIMOS9Mzk', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 86, 'output_tokens': 43, 'total_tokens': 129, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# ⏱️  Execution Time: 1.06 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
# 🛠️  Tool Selected: run_network_diagnostic
# ℹ️  Arguments: {}
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 91, 'total_tokens': 123, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEjDA4tiRifwF7ERu0jHCxktj9d', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019f4d48-fdce-7a90-bdbe-239062f781f5-0' tool_calls=[{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_1WjVZX3Iler9YYKtJl3wmkuo', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 91, 'output_tokens': 32, 'total_tokens': 123, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ▶ TOOL DECISION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
# ⏱️  Execution Time: 1.09 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ Tool Call Detected
# 🛠️  Tool Selected: lookup_invoice
# ℹ️  Arguments: {'customer_id': 'C001'}
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  lookup_invoice()
#
# ▶ INPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# C001
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "customer_id": "C001",
#     "invoice_amount": 1299,
#     "status": "PENDING"
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOOL EXECUTION
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🛠️  run_network_diagnostic()
#
# ▶ OUTPUT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#     "signal_strength": "WEAK",
#     "tower_status": "ACTIVE",
#     "issue_found": true
# }
# ⏱️  Execution Time: 0.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  BILLING AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Rajan
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Rajan, Telecom Billing Agent.
#
# Responsibilities:
# - Invoice support
# - Billing issues
#
# Rules:
# - Always lookup invoice first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'lookup_invoice', 'args': {'customer_id': 'C001'}, 'id': 'call_1WjVZX3Iler9YYKtJl3wmkuo', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'customer_id': 'C001', 'invoice_amount': 1299, 'status': 'PENDING'}
# 🧠 Calling Billing LLM
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TECH AGENT STARTED
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# 🤖 Agent: Priya
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  WHAT LLM IS SEEING
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ MESSAGE 1
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: SystemMessage
#
# CONTENT:
#
#
# You are Priya, Telecom Technical Agent.
#
# Responsibilities:
# - Slow internet
# - Network issues
#
# Rules:
# - Always run diagnostics first
#
#
# ▶ MESSAGE 2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: AIMessage
#
# CONTENT:
#
#
#
# TOOL CALLS:
#
# [{'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_wF9neahVsQPzO6Mg4JPTpLj5', 'type': 'tool_call'}, {'name': 'run_network_diagnostic', 'args': {}, 'id': 'call_hJ1dDQwzyxxbniEpIMOS9Mzk', 'type': 'tool_call'}]
#
# ▶ MESSAGE 3
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'signal_strength': 'WEAK', 'tower_status': 'ACTIVE', 'issue_found': True}
#
# ▶ MESSAGE 4
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# TYPE: ToolMessage
#
# CONTENT:
#
# {'signal_strength': 'WEAK', 'tower_status': 'ACTIVE', 'issue_found': True}
# 🧠 Calling Tech LLM
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The diagnostics indicate that there is a weak signal strength, but the tower status is active. This suggests that there may be network issues affecting your internet speed. \n\nWould you like assistance with troubleshooting further or exploring potential solutions?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 160, 'total_tokens': 205, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E0AEkJQUXaJq1oIl7EXDUzmyUrTK8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d49-0215-7ee1-a5ac-e6e9ff8ffd6e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 160, 'output_tokens': 45, 'total_tokens': 205, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.0 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
# ▶ RAW LLM RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# content='The invoice details for customer ID C001 are as follows:\n\n- **Invoice Amount:** $1299\n- **Status:** PENDING\n\nIf you have any specific questions or need assistance regarding this invoice, please let me know!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 114, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2247163164', 'id': 'chatcmpl-E0AEkwbOG8WbSUjON3rQAY4lvcMEB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4d49-0212-75c3-876c-c436bd9a940f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 114, 'output_tokens': 47, 'total_tokens': 161, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ⏱️  Execution Time: 1.23 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  CHECKING TOOL CALLS
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⚠️  No Tool Calls Found
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  COMBINER AGENT
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ▶ AGENT OUTPUTS
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BILLING OUTPUT:
#
# The invoice details for customer ID C001 are as follows:
#
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or need assistance regarding this invoice, please let me know!
#
# TECH OUTPUT:
#
# The diagnostics indicate that there is a weak signal strength, but the tower status is active. This suggests that there may be network issues affecting your internet speed.
#
# Would you like assistance with troubleshooting further or exploring potential solutions?
# 🧠 Combining Agent Outputs
#
# ▶ FINAL COMBINED RESPONSE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Subject: Invoice Details and Network Issue Assistance
#
# Dear Customer,
#
# Thank you for reaching out. Here are the details regarding your invoice and the current network status:
#
# **Invoice Information:**
# - **Customer ID:** C001
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or need assistance regarding this invoice, please feel free to ask.
#
# **Network Diagnostics:**
# Our diagnostics indicate that there is a weak signal strength, although the tower status is active. This may be affecting your internet speed. If you would like assistance with troubleshooting or exploring potential solutions, please let us know.
#
# We are here to help!
#
# Best regards,
# [Your Name]
# [Your Position]
# [Your Company]
# [Contact Information]
# ⏱️  Execution Time: 3.18 sec
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  FINAL RESPONSE
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#
#
#     Internet speed is poor and payment confirmation is pending. My Customer Id is C001.
#
#
#
# Subject: Invoice Details and Network Issue Assistance
#
# Dear Customer,
#
# Thank you for reaching out. Here are the details regarding your invoice and the current network status:
#
# **Invoice Information:**
# - **Customer ID:** C001
# - **Invoice Amount:** $1299
# - **Status:** PENDING
#
# If you have any specific questions or need assistance regarding this invoice, please feel free to ask.
#
# **Network Diagnostics:**
# Our diagnostics indicate that there is a weak signal strength, although the tower status is active. This may be affecting your internet speed. If you would like assistance with troubleshooting or exploring potential solutions, please let us know.
#
# We are here to help!
#
# Best regards,
# [Your Name]
# [Your Position]
# [Your Company]
# [Contact Information]
#
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#  TOTAL EXECUTION TIME
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ⏱️  Execution Time: 5.51 sec
